# %% [markdown]
# <a href="https://colab.research.google.com/github/VijayDassss/Python-Practice-/blob/main/ProjectPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# created a Sample DataFrame For Project
data = {
    'Date': pd.date_range('2023-01-01', periods=10),
    'Product': np.random.choice(['Honda', 'Mahindra', 'Tata',"Mercides","Volswagn","pojero","Loamborgini","ferrari"], size=10),
    'Quantity': np.random.randint(1, 10, size=10),
    'Revenue': np.random.uniform(50, 200, size=10)
}

df = pd.DataFrame(data)
df.to_csv('sales_data.csv', index=False)

# %%
df=pd.read_csv('sales_data.csv')
df
#Here i had located file in my computer and called it in colab to work on
# Out:
#          Date   Product  Quantity     Revenue
# 0  2023-01-01  Volswagn         3  163.570300
# 1  2023-01-02   ferrari         1  142.441039
# 2  2023-01-03  Mercides         2  107.978479
# 3  2023-01-04   ferrari         9   88.741927
# 4  2023-01-05    pojero         7  125.221371
# 5  2023-01-06    pojero         9  131.621695
# 6  2023-01-07      Tata         3  123.359629
# 7  2023-01-08  Volswagn         7   99.863009
# 8  2023-01-09  Mahindra         6  169.812890
# 9  2023-01-10  Mercides         9  124.192066

# %%
df.head()
#Csv File Data is been loaded to Check its structure
# Out:
#          Date   Product  Quantity     Revenue
# 0  2023-01-01  Volswagn         3  163.570300
# 1  2023-01-02   ferrari         1  142.441039
# 2  2023-01-03  Mercides         2  107.978479
# 3  2023-01-04   ferrari         9   88.741927
# 4  2023-01-05    pojero         7  125.221371

# %%
df.isna()
#to find missig values in Data
# Out:
#     Date  Product  Quantity  Revenue
# 0  False    False     False    False
# 1  False    False     False    False
# 2  False    False     False    False
# 3  False    False     False    False
# 4  False    False     False    False
# 5  False    False     False    False
# 6  False    False     False    False
# 7  False    False     False    False
# 8  False    False     False    False
# 9  False    False     False    False

# %%
df.duplicated()
#to find duplicate values in Data
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
per75=np.percentile(df["Revenue"],75)
per25=np.percentile(df["Revenue"],25)
iqr=per75-per25
upper_limit=per75*1.5*iqr
print(upper_limit)
Revenue_per=df[df["Revenue"]>upper_limit]
Revenue_per
#to find  outlier in the Revenue
# Out:
# 5850.566925269204
# Empty DataFrame
# Columns: [Date, Product, Quantity, Revenue]
# Index: []

# %%
#Box Plot to get a Clear Idea
import matplotlib.pyplot as plt
plt.boxplot(df["Revenue"])
plt.title(f"Revenue_chart from 23-01-01 to 23-01-10 ")
plt.xlabel('Revenue')
plt.show()

# %%
#by looking this plot we can say from 23-01-01 to 23-01-10 Revenue lies between 50 to 190

# %%
#bar plot to compare Quality and Revenue
Product_df=df.groupby("Product").sum().reset_index()
Product_df
# Out:
# <ipython-input-79-631641f85e6a>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Product_df=df.groupby("Product").sum().reset_index()
#     Product  Quantity     Revenue
# 0  Mahindra         6  169.812890
# 1  Mercides        11  232.170545
# 2      Tata         3  123.359629
# 3  Volswagn        10  263.433309
# 4   ferrari        10  231.182966
# 5    pojero        16  256.843066

# %%
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named df with columns like "Product" and "Quantity"
Product_df = df.groupby("Product")["Quantity"].sum().reset_index()

# Plotting the data
plt.bar(Product_df["Product"], Product_df["Quantity"],color="blue",linewidth=3)
plt.title(f" Product Average sales on Quantity",fontsize=20,color="green")
plt.xlabel('Product', fontsize=20,color="red")
plt.ylabel('Quantity', fontsize=20,color="red")
# Display the plot
plt.show()

# %%
#in this graph as you can see the highest sales was done by Pojero and the lowest sales was done by Tata
